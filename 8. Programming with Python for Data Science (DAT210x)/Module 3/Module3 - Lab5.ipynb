# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module3 - Lab5

# %% [markdown]
# This code is intentionally missing! Read the directions on the course lab page!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# This is new
from pandas.tools.plotting import andrews_curves

# %%
# Look pretty...

# matplotlib.style.use('ggplot')
plt.style.use('ggplot')

# %%
wheat_seeds = pd.read_csv("Datasets/wheat.data", index_col=0)

# %%
plt.figure()
andrews_curves(wheat_seeds, 'wheat_type', alpha=0.4)
# Out:
# C:\Users\Ikos\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.andrews_curves' is deprecated, import 'pandas.plotting.andrews_curves' instead.

# %%
# Display the graphs:
plt.show()

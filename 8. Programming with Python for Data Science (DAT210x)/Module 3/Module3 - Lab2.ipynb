# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module3 - Lab2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
# Look pretty...

# matplotlib.style.use('ggplot')
plt.style.use('ggplot')

# %% [markdown]
# Load up the wheat seeds dataset into a dataframe. We've stored a copy in the Datasets directory.

# %%
wheat_seeds = pd.read_csv("Datasets/wheat.data", index_col=0)

# %% [markdown]
# Create a 2d scatter plot that graphs the `area` and `perimeter` features:

# %%
wheat_seeds.plot.scatter(x='area', y='perimeter')

# %% [markdown]
# Create a 2d scatter plot that graphs the `groove` and `asymmetry` features:

# %%
wheat_seeds.plot.scatter(x='groove', y='asymmetry')

# %% [markdown]
# Create a 2d scatter plot that graphs the `compactness` and `width` features:

# %%
wheat_seeds.plot.scatter(x='compactness', y='width')

# %%
plt.show()

# %% [markdown]
# ### BONUS
#
# After completing the above, go ahead and run your program Check out the results, and see what happens when you add in the optional display parameter marker with values of either `'^'`, `'.'`, or `'o'`:

# %%
wheat_seeds.plot.scatter(x='area', y='perimeter', marker='^')
wheat_seeds.plot.scatter(x='groove', y='asymmetry', marker='o')
wheat_seeds.plot.scatter(x='compactness', y='width', marker='.')

# %%
# Display the graphs:
plt.show()

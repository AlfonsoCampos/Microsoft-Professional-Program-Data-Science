# %%
library("AzureML")
ws <- workspace()
dat <- download.intermediate.dataset(
  ws,
  experiment = "ae4c6f4dbab04496af447af010096b90.f-id.8ed6e2d7c99e49f9bb3bfd7081e4f17a",
  node_id = "4725b9f6-573d-4241-a0d6-436943593c54-847",
  port_name = "Results dataset",
  data_type_id = "GenericCSV"
)

# %%
head(dat)
# Out:
#   CheckingAcctStat Duration   CreditHistory Purpose Savings Employment
# 1 A11              0.20588235 A32           A43     A61     A73
# 2 A14              0.29411765 A32           A43     A62     A74
# 3 A14              0.20588235 A32           A43     A61     A73
# 4 A11              0.64705882 A32           A43     A61     A73
# 5 A13              0.02941176 A33           A43     A61     A72
# 6 A11              0.02941176 A32           A43     A63     A73
#   InstallmentRatePecnt PresentResidenceTime Property Age        Telephone
# 1 0.3333333            0.3333333            A121     0.08928571 A191
# 2 1.0000000            0.6666667            A122     0.12500000 A192
# 3 1.0000000            0.3333333            A124     0.23214286 A192
# 4 0.6666667            0.3333333            A123     0.21428571 A192
# 5 0.3333333            0.0000000            A122     0.17857143 A191
# 6 0.3333333            0.6666667            A121     0.44642857 A191
#   CreditStatus
# 1 1
# 2 0
# ...

# %%
str(dat)
# Out:
# 'data.frame':	950 obs. of  12 variables:
#  $ CheckingAcctStat    : chr  "A11" "A14" "A14" "A11" ...
#  $ Duration            : num  0.2059 0.2941 0.2059 0.6471 0.0294 ...
#  $ CreditHistory       : chr  "A32" "A32" "A32" "A32" ...
#  $ Purpose             : chr  "A43" "A43" "A43" "A43" ...
#  $ Savings             : chr  "A61" "A62" "A61" "A61" ...
#  $ Employment          : chr  "A73" "A74" "A73" "A73" ...
#  $ InstallmentRatePecnt: num  0.333 1 1 0.667 0.333 ...
#  $ PresentResidenceTime: num  0.333 0.667 0.333 0.333 0 ...
#  $ Property            : chr  "A121" "A122" "A124" "A123" ...
#  $ Age                 : num  0.0893 0.125 0.2321 0.2143 0.1786 ...
#  $ Telephone           : chr  "A191" "A192" "A192" "A192" ...
#  $ CreditStatus        : int  1 0 0 1 0 0 1 1 0 0 ...
